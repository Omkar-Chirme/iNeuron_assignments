# %% [markdown]
# # Assignment 1
# ## Python Basics
#
# **1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.**
#
#   * = mathematical operators
#
#   'hello'= String
#
#   -87.8 = Float
#
#   - = mathematical operators
#
#   / = mathematical operators
#
#   6 = Interger
#
# **2. What is the difference between string and variable?**
#
# Variable is container which holds any type of data, where as strig is a data type in which data is closed my single or double inverted cuammas '' or "". string is mutable and can be indexed.
#
# **3. Describe three different data types.**
#
# String, integers, float.
#
# **4. What is an expression made up of? What do all expressions do?**
#
# Expressions may contain integers and strings and mathematical operators. Epression can add, substract, multiply or divide and can also perform Logical operations like <,>,==,<=.=>,!=
#
# **5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?**
#
# In an expression variable spam is equal to value 10.
# In a statement spam is declare as a variable having value as 10.
#
# **6. After running the following code, what does the variable bacon contain?**
#
# bacon = 22
#
# bacon + 1
#
# Output: Variable bacon contains integer 23. (bacon = 23)
#
# **7. What should the values of the following two terms be?**
#
# 'spam' + 'spamspam' :- 'spamspamspam'
#
# 'spam' * 3 :- 'spamspamspam'
#
# **8. Why is eggs a valid variable name while 100 is invalid?**
#
# In python Variable name can be started by letters or _ , but never by any intergers. Therefore variable name cannot be 100 or any name starting by integers
#
# **9. What three functions can be used to get the integer, floating-point number, or string version of a value?**
#
# int() for integer
#
# float() for float
#
# str() for string
#
# **10. Why does this expression cause an error? How can you fix it?**
# **'I have eaten ' + 99 + ' burritos.'**
#
# Here we are trying to add an integer in a string that we cannot do. To fix this we must type 99 in closed inverted cuammas '99' to treat 99 as string. Therefore
#
# 'I have eaten ' + '99' + ' burritos.'
# will give us desired output.
